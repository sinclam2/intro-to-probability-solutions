# %% [markdown]
# # Is the Markov chain in Example 11.11 erdogic?

# %% [markdown]
# ______
#
# ![](../11.1-intro-to-markov-chains/images/11.11-matrix.PNG)

# %% [markdown]
# # This process has absorbing states $\implies$ not erdogic
